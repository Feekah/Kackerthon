# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
#import data
train = pd.read_csv('trains.csv')
test = pd.read_csv('tests.csv')
sub = pd.read_csv('sample_submission.csv')

# %%
train.head()
# Out:
#          customer_id  age          job  marital          education  default  \
# 0  customer_id_39075   31       admin.  married  university.degree       no
# 1  customer_id_34855   31   technician   single  university.degree       no
# 2   customer_id_7107   47  blue-collar  married           basic.6y  unknown
# 3  customer_id_31614   36     services  married  university.degree       no
# 4  customer_id_34878   34       admin.   single        high.school       no
#
#   housing loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0      no   no   cellular   dec  ...        3    999         1      failure
# 1      no   no  telephone   may  ...        4    999         0  nonexistent
# 2     yes   no  telephone   may  ...        2    999         0  nonexistent
# 3      no   no   cellular   may  ...        1    999         1      failure
# 4      no   no   cellular   may  ...        9    999         0  nonexistent
#
# ...

# %%
test.head()
# Out:
#          customer_id  age          job  marital    education  default housing  \
# 0  customer_id_32884   59   technician  married  high.school       no      no
# 1   customer_id_3169   57      unknown  married      unknown  unknown     yes
# 2  customer_id_32206   35  blue-collar  married     basic.9y       no      no
# 3   customer_id_9403   38       admin.  married  high.school       no      no
# 4  customer_id_14020   29    housemaid  married  high.school       no     yes
#
#   loan    contact month  ...  duration  campaign  pdays  previous  \
# 0  yes   cellular   may  ...  6.183333         1    999         1
# 1   no  telephone   may  ...  4.750000         2    999         0
# 2   no   cellular   may  ...  0.866667         1    999         1
# 3   no  telephone   jun  ...  5.916667         4    999         0
# 4   no   cellular   jul  ...  3.150000         2    999         0
#
#       poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# ...

# %%
sub.head()
# Out:
#          customer_id  subscribed
# 0  customer_id_32884           1
# 1   customer_id_3169           1
# 2  customer_id_32206           1
# 3   customer_id_9403           1
# 4  customer_id_14020           1

# %%
# check test and train shape
print(test.shape, train.shape)
# Out:
# (12357, 21) (28831, 22)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28831 entries, 0 to 28830
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     28831 non-null  object
#  1   age             28831 non-null  int64
#  2   job             28831 non-null  object
#  3   marital         28831 non-null  object
#  4   education       28831 non-null  object
#  5   default         28831 non-null  object
#  6   housing         28831 non-null  object
#  7   loan            28831 non-null  object
#  8   contact         28831 non-null  object
#  9   month           28831 non-null  object
#  10  day_of_week     28831 non-null  object
#  11  duration        28831 non-null  float64
#  12  campaign        28831 non-null  int64
#  13  pdays           28831 non-null  int64
#  14  previous        28831 non-null  int64
#  15  poutcome        28831 non-null  object
#  16  emp_var_rate    28831 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12357 entries, 0 to 12356
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     12357 non-null  object
#  1   age             12357 non-null  int64
#  2   job             12357 non-null  object
#  3   marital         12357 non-null  object
#  4   education       12357 non-null  object
#  5   default         12357 non-null  object
#  6   housing         12357 non-null  object
#  7   loan            12357 non-null  object
#  8   contact         12357 non-null  object
#  9   month           12357 non-null  object
#  10  day_of_week     12357 non-null  object
#  11  duration        12357 non-null  float64
#  12  campaign        12357 non-null  int64
#  13  pdays           12357 non-null  int64
#  14  previous        12357 non-null  int64
#  15  poutcome        12357 non-null  object
#  16  emp_var_rate    12357 non-null  float64
# ...

# %%
# check the percentage of each category in the target variable
train['subscribed'].value_counts(normalize=True)
# Out:
# 0    0.887239
# 1    0.112761
# Name: subscribed, dtype: float64

# %%
# countplot of each category in the target variable
sns.countplot(train['subscribed'].map({0: 'No', 1: 'Yes'}));
# Out:
# C:\Users\otadeyemi\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# concatenate train and test data, check 5 random observations
test['subscribed'] = 'test'
data = pd.concat([train, test]).reset_index(drop=True)
data.sample(5)
# Out:
#              customer_id  age          job  marital          education  \
# 14948  customer_id_39217   44  blue-collar  married           basic.6y
# 38407  customer_id_30838   53  blue-collar  married           basic.6y
# 34197  customer_id_15557   26   technician   single            unknown
# 24436  customer_id_33678   25      student   single        high.school
# 3899   customer_id_23046   50   technician  married  university.degree
#
#       default  housing     loan   contact month  ... campaign  pdays  \
# 14948      no      yes      yes  cellular   mar  ...        1      7
# 38407      no  unknown  unknown  cellular   may  ...        2    999
# 34197      no       no       no  cellular   jul  ...        2    999
# 24436      no      yes       no  cellular   may  ...        1    999
# 3899       no      yes       no  cellular   aug  ...        1    999
#
#        previous     poutcome  emp_var_rate cons_price_idx  cons_conf_idx  \
# ...

# %%
# data shape
data.shape
# Out:
# (41188, 22)

# %%
# drop redundant columns
data.drop(['customer_id','contact','day_of_week','emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed'], axis=1, inplace=True)
data.head()
# Out:
#    age          job  marital          education  default housing loan month  \
# 0   31       admin.  married  university.degree       no      no   no   dec
# 1   31   technician   single  university.degree       no      no   no   may
# 2   47  blue-collar  married           basic.6y  unknown     yes   no   may
# 3   36     services  married  university.degree       no      no   no   may
# 4   34       admin.   single        high.school       no      no   no   may
#
#     duration  campaign  pdays  previous     poutcome subscribed
# 0   1.283333         3    999         1      failure          0
# 1   0.200000         4    999         0  nonexistent          0
# 2   4.616667         2    999         0  nonexistent          0
# 3   1.166667         1    999         1      failure          0
# 4  19.683333         9    999         0  nonexistent          0

# %%
# label encode categorical features 
cols = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'month', 'poutcome']

for col in cols:
    data[col] = pd.factorize(data[col])[0]
data.head(10)
# Out:
#    age  job  marital  education  default  housing  loan  month   duration  \
# 0   31    0        0          0        0        0     0      0   1.283333
# 1   31    1        1          0        0        0     0      1   0.200000
# 2   47    2        0          1        1        1     0      1   4.616667
# 3   36    3        0          0        0        0     0      1   1.166667
# 4   34    0        1          2        0        0     0      1  19.683333
# 5   48    4        0          0        0        1     1      2   1.300000
# 6   34    2        1          3        1        0     0      3   2.366667
# 7   34    1        1          4        0        0     0      4   8.733333
# 8   39    5        1          0        0        1     0      5   7.200000
# 9   40    1        1          4        0        2     2      4   0.983333
#
#    campaign  pdays  previous  poutcome subscribed
# 0         3    999         1         0          0
# 1         4    999         0         1          0
# ...

# %%
# get back to train and test set
train_df = data.loc[(data['subscribed'] != 'test')].reset_index(drop = True)
test_df = data.loc[(data['subscribed'] == 'test')].reset_index(drop = True)

# %%
print(train_df.shape, test_df.shape)
# Out:
# (28831, 14) (12357, 14)

# %%
X = train_df.drop(['subscribed'], axis=1)
y = train_df['subscribed']
# this solved the bug we had in class, y was an object before 
# which wont work we some models, so we change its type to int
y = y.astype('int')

# %%
print(X.shape, y.shape)
# Out:
# (28831, 13) (28831,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

# %%
X_train, X_test, y_train,  y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (23064, 13) (23064,)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict = model.predict(X_test)
predict
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
prob_predict = model.predict_proba(X_test)[:,1]
prob_predict
# Out:
# array([0.02, 0.  , 0.03, ..., 0.2 , 0.03, 0.09])

# %%
accuracy = accuracy_score(y_test, predict)
accuracy
# Out:
# 0.9068839951447893

# %%
f1 = f1_score(y_test, predict)
f1
# Out:
# 0.470935960591133

# %%
print('{} accuracy is: {:.4f}'.format(type(model).__name__, accuracy))
print('{} F1 score is: {:.4f}'.format(type(model).__name__, f1))
# Out:
# RandomForestClassifier accuracy is: 0.9069
# RandomForestClassifier F1 score is: 0.4709

# %%
test_df.head()
# Out:
#    age  job  marital  education  default  housing  loan  month  duration  \
# 0   59    1        0          2        0        0     1      1  6.183333
# 1   57    8        0          6        1        1     0      1  4.750000
# 2   35    2        0          5        0        0     0      1  0.866667
# 3   38    0        0          2        0        0     0      4  5.916667
# 4   29    6        0          2        0        1     0      3  3.150000
#
#    campaign  pdays  previous  poutcome
# 0         1    999         1         0
# 1         2    999         0         1
# 2         1    999         1         0
# 3         4    999         0         1
# 4         2    999         0         1

# %%
# drop survived column, we added it during concatenation
test_df.drop(['subscribed'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-537a3fd7be19> in <module>
#       1 # drop survived column, we added it during concatenation
# ----> 2 test_df.drop(['subscribed'], axis=1, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
# predict on test data
pred = model.predict(test_df)

# %%
sub['Survived'] = pred
sub.head()
# Out:
#          customer_id  subscribed  Survived
# 0  customer_id_32884           0         0
# 1   customer_id_3169           0         0
# 2  customer_id_32206           0         0
# 3   customer_id_9403           0         0
# 4  customer_id_14020           0         0

# %%
sub.drop(['Survived'], axis=1, inplace=True)
sub.head()
# Out:
#          customer_id  subscribed
# 0  customer_id_32884           0
# 1   customer_id_3169           0
# 2  customer_id_32206           0
# 3   customer_id_9403           0
# 4  customer_id_14020           0

# %%
# make submission file 
sub.to_csv('submission.csv', index = False)
